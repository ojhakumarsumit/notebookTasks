# %% [markdown]
# # Sample Notebook Task
# This notebook demonstrates a simple execution task.

# %%
import calendar
year = 2023
month = 12
print('Generating calendar for:', month, year)

# %%
print(calendar.month(year, month))

# %%
numbers = [1,2,3,4,5]
total = sum(numbers)
print('Sum of numbers:', total)
